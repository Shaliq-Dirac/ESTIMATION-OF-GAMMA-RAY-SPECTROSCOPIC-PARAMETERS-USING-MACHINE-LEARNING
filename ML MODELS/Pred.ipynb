# %%
## IMPORTING ALL THE NECESSARY LIBRARIES
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression 
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR  # For regression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn import svm
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# LOADING THE DATA
path = r""   ## SPECIFY THE PATH WHERE CSV FILE IS LOCATED
data = pd.read_csv(path)

# %%
## DEFINING INPUT(ENERGY) AND OUTPUT(COUNTS)
X = data.iloc[:, 0].values.reshape(-1, 1) # energy input
y = data.iloc[:, 1:].values # 2101 data values

# %%
#LINEAR REGRESSION MODEL
lr= LinearRegression()
lr.fit(X, y)

# %%
#RANDOM FOREST MODEL
rf = RandomForestRegressor(n_estimators=500, random_state=92)
rf.fit(X, y)

# %%
# DECISION TREE MODEL
dt = DecisionTreeRegressor(random_state=92)
dt.fit(X, y)

# %%
# KNN REGRESSION MODEL
knn = KNeighborsRegressor(n_neighbors=5)
knn.fit(X_train, y_train)

# %%
# PREDECTION TEST DATA
y_pred = MODEL.predict(X_test)

## switch the model accordingly for example 
# To use linear Regression change the "model" to "lr"

# %%
# PERFORMANCE OF THE MODEL
mse = mean_squared_error(y_test, y_pred)
print("Mean squared error:", mse)

# %%
# PREDICTIONS ON NEW DATA           
# ENTER THE NEW ENERGY VALUE TO PREDICT
# SWITCH THE MODEL ACCORDINGLY FOR EXAMPLE 
##TO USE RANDOM FOREST CHANGE THE "MODEL" TO "rf"
new_X= [[525.0]]
new_y_pred = MODEL.predict(new_X)
print("Predicted values for an energy input of 155:", new_y_pred)

# %%
# predicted values
output_df = pd.DataFrame({'Predicted Values': new_y_pred.ravel()})
output_df.to_csv('', index=True)    ## SPECIFY THE PATH WHERE THIS CSV FILE NEEDED TO STORED LOCATED
print(output_df)
